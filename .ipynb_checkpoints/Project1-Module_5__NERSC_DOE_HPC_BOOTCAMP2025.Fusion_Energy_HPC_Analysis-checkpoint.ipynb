# %% [markdown]
# <img src=https://www.nersc.gov/_resources/themes/nersc/images/NERSC_logo_no_spacing.svg width="500">
#
# ### National Energy Research Scientific Computing Center
# #### Introduction to High Performance Computing Bootcamp 2025
#
# # Module 5: Project -HPC Workload and Energy Analysis in Fusion Research

# %% [markdown]
# ## 🎯 Learning Outcomes
#
# By the end of this project, you will be able to:
#
# - Investigate HPC resource utilization patterns in fusion energy research using Python.
# - Interpret performance data and scaling behaviors across fusion workloads at NERSC.
# - Collaborate on proposing optimizations and insights to improve the efficiency of fusion simulations.

# %% [markdown]
# # Module 5 Project 1 — Fusion Energy: Performance & Energy Trade-off Analysis
#
# ## Project Overview
#
# In this project, you will **synthesize knowledge** from the four core modules to develop a **theoretical performance and energy strategy** for DOE-class fusion workloads.
# This is not a coding-heavy, data-crunching exercise — instead, it’s a **thinking project** where you interpret existing patterns, apply HPC concepts, and reason through trade-offs without needing to run the jobs yourselves.
#
# ---
#
# ## Context
# You have completed these core modules:
# 1. **Understanding Power Consumption in Computers** — how hardware components consume energy and how system-level power is measured.
# 2. **Top 500 Supercomputers Analysis** — interpreting large-scale performance rankings and efficiency metrics.
# 3. **NERSC Users and Application Power & Energy Analysis** — recognizing real-world workload profiles and facility-level energy patterns.
# 4. **Optimization Techniques and Performance Profiling** — understanding where energy savings and performance gains can be found.
#
# ---
#
# ## Your Task
# You will **apply these learnings** to the context of *fusion energy research* — one of DOE’s high-impact computational science areas. Using **hypothetical but realistic scenarios**, you will reason through how performance, energy use, and system architecture influence decision-making.
#
# You may choose **one of two thinking tracks**:
#
# **Option A — Theoretical Workflow Efficiency Analysis**
# - Compare three types of fusion workloads (e.g., large-scale plasma simulation, diagnostics data analysis, ML-based prediction).
# - For each, reason through:
#   - Likely compute architecture (CPU vs GPU mix, memory needs).
#   - Expected scaling characteristics and their impact on efficiency.
#   - Theoretical performance per watt compared to current DOE supercomputers.
# - Summarize how you would prioritize hardware and scheduling for maximum throughput.
#
# **Option B — Theoretical Scheduling & Capacity Planning**
# - Given a fixed facility power budget and an assumed mix of fusion jobs, propose:
#   - A scheduling approach that balances peak performance and energy efficiency.
#   - Strategies for aligning with DOE’s sustainability and cost goals.
# - Consider trade-offs between throughput, fairness, and energy footprint.
# - Justify your decisions using reasoning from Modules 1–4.
#
# ---
#
# ### What You’ll Practice
# - Translating **technical metrics** into facility-level strategy.
# - Integrating knowledge from **power measurement, system rankings, workload profiling, and optimization**.
# - Reasoning about **trade-offs** without requiring live experiments.
# - Communicating recommendations in **clear, evidence-backed language**.
#
# > Remember: This is about *how you think* as an HPC strategist, not just what the numbers say. Focus on clarity, logical flow, and alignment with DOE mission priorities.

# %% [markdown]
# ## 🌟 Introduction
#
#
# Welcome to the **Fusion Energy & High-Performance Computing (HPC)** module — an exciting journey into the technologies powering the **future of clean energy** and scientific discovery!
#
# Fusion energy — the process that powers the Sun — promises a virtually limitless and sustainable source of energy for our planet. Researchers across the globe, including at leading **U.S. Department of Energy (DOE)** laboratories, are working to bring this stellar energy source to Earth.
#
# However, harnessing fusion isn't easy. It involves **extreme conditions**, **complex physics**, and **massive data volumes**. That's where **High-Performance Computing (HPC)** comes in. DOE labs like [LLNL](https://www.llnl.gov/), [ORNL](https://www.ornl.gov/), and [PPPL](https://www.pppl.gov/) rely on some of the **fastest supercomputers in the world** to simulate plasma behavior, optimize reactor designs, and process experimental data.
#
# ---
#
# ### 🌐 Why Fusion + HPC?
#
# - 🔬 **Modeling extreme plasma physics** — where temperatures exceed millions of degrees.
# - 🧠 **Training AI/ML models** to predict reactor behavior.
# - ⚙️ **Designing and testing reactor materials** under intense conditions.
# - 📈 **Analyzing massive datasets** from experiments and simulations.
#
# ---
#
# ### 🖼️ Visual: Fusion & Supercomputing
#
# ![Fusion Energy](https://upload.wikimedia.org/wikipedia/commons/thumb/9/98/NIF_target_chamber.jpg/800px-NIF_target_chamber.jpg)
# *Image: Target chamber of the National Ignition Facility (NIF), a fusion experiment at LLNL.*
# *Source: Wikimedia Commons*
#
# ---
#
# By the end of this module, you'll gain insight into how **HPC accelerates breakthroughs** in fusion research — and how your future work can contribute to this critical mission.
#
# Let’s ignite the stars here on Earth — together. 🌟🌍

# %% [markdown]
# ## 💡 Goals of this Module
#
# This 3-day project module is designed to help you explore how **fusion energy research** and **high-performance computing** intersect in real-world DOE applications.
#
# By the end of this module, you will be able to:
#
# 🔹 **Explain** the fundamentals of fusion energy and how it differs from fission.
# 🔹 **Understand** why HPC systems are essential for modeling fusion reactions.
# 🔹 **Analyze** synthetic fusion workload data using Python and common scientific libraries.
# 🔹 **Visualize** patterns in computational demand across DOE fusion experiments.
# 🔹 **Present findings** in a short group report simulating a DOE project debrief.
#
# This project combines **scientific computing**, **data analysis**, and **real-world DOE mission contexts**, giving you a unique opportunity to contribute to one of the most important scientific challenges of our time.

# %% [markdown]
# ## Data & Assumptions
#
# To guide your theoretical reasoning, we will work with a **detailed conceptual dataset** based on patterns from Modules 1–4.
# You do **not** need to load this into Python — it’s here to give you realistic values to think about when making decisions.
#
# ---
#
# ### Hypothetical Fusion Workload Profiles
#
# | Workload Type                  | Architecture Preference | Runtime (Hours) | Nodes Used | Power per Node (kW) | Total Power (MW) | Est. Scaling Efficiency (%) | Memory per Node (GB) | Interconnect Usage | Notes |
# |--------------------------------|--------------------------|-----------------|------------|---------------------|------------------|-----------------------------|----------------------|--------------------|-------|
# | Large-Scale Plasma Simulation  | GPU-heavy hybrid         | 12              | 512        | 6.5                 | 3.33             | 78                          | 512                  | Very High          | Heavy MPI comms; sensitive to interconnect latency. |
# | Diagnostics Data Analysis      | CPU-heavy                | 4               | 256        | 4.2                 | 1.07             | 85                          | 1024                 | Medium             | Memory-bound; performance depends on I/O throughput. |
# | ML-Based Prediction Model      | GPU-accelerated          | 2               | 128        | 7.0                 | 0.90             | 92                          | 256                  | Low                | Embarrassingly parallel; minimal comm overhead. |
# | Data Assimilation (Hybrid)     | Balanced CPU/GPU         | 6               | 200        | 5.0                 | 1.00             | 88                          | 512                  | Medium-High        | Integrates real-time experimental data with simulation state. |
# | Small Parameter Sweep Simulations | CPU-heavy batch        | 1               | 64         | 3.8                 | 0.24             | 80                          | 128                  | Low                | Many small independent jobs; ideal for opportunistic backfill. |
#
# ---
#
# ### Theoretical Facility Context
# - **Power Budget**: 12 MW total facility limit for all workloads combined.
# - **Queue Mix (Typical Week)**:
#   - 40% Large-Scale Plasma Simulation
#   - 25% Diagnostics Data Analysis
#   - 15% ML Prediction
#   - 10% Data Assimilation
#   - 10% Small Parameter Sweeps
# - **Electricity Price**: \$0.10 per kWh (use for cost reasoning).
# - **Target DOE Goals**:
#   - Increase science throughput per kWh by **20%** over 3 years.
#   - Maintain **balanced resource access** for different project teams.
#   - Prioritize workloads that accelerate **fusion ignition research milestones**.
#
# ---
#
# ### Calculations You Can Perform
#
# **1. Energy Use per Job**
# $$
# \text{kWh} = \text{Runtime (h)} \times \text{Nodes Used} \times \text{Power per Node (kW)}
# $$
#
# **2. Performance per Watt Reasoning**
# - Compare scaling efficiency (%) × architecture type with Green500-style metrics.
# - Consider where GPUs offer the most *real* benefit per watt.
#
# **3. Throughput Under Power Cap**
# - If the total running workloads exceed **12 MW**, determine which workloads to prioritize or delay.
# - Consider *mix* strategies: e.g., run ML workloads during simulation off-hours to flatten power peaks.
#
# **4. Cost Estimation**
# $$
# \text{Cost per Job (\$)} = \text{kWh} \times 0.10
# $$
#
# ---
#
# ### How to Use This in Your Project
# - **Option A** (Workflow Efficiency) → Identify workloads with the best *science per watt* potential and suggest hardware/config tweaks that could improve them.
# - **Option B** (Scheduling & Planning) → Model (on paper) a weekly schedule that stays under 12 MW but maximizes total science output.
#
# > Be explicit about all **assumptions** you make: node utilization, queue wait times, efficiency improvements, or workload scaling limits.

# %% [markdown]
# ## 🖥️ HPC Systems Used for Fusion Research (Updated for 2025)
#
# DOE researchers rely on some of the world’s most powerful supercomputers to simulate the complex physics of plasma confinement, materials under stress, and edge-plasma interactions—key for both tokamak and laser-based fusion approaches.
#
# ---
#
# ### 🔷 Notable Supercomputers (2025)
#
# | System       | Facility | Highlights |
# |--------------|----------|------------|
# | **El Capitan** (LLNL) | Lawrence Livermore | World’s fastest supercomputer as of June 2025 (1.742 exaFLOPS Rmax). CPU–GPU APU design supports advanced fusion materials modeling, chamber-scale plasma simulations, and multi-physics workflows. |
# | **Frontier** (ORNL) | Oak Ridge | DOE’s first exascale system (~1.35 exaFLOPS). Used extensively for codes like CGYRO and XGC to study edge plasma turbulence, confinement optimization, and disruption prediction. |
# | **Aurora** (ANL) | Argonne | Intel/Cray exascale platform (1+ exaFLOPS) powering integrated fusion simulations, ML-based plasma control, and workflow orchestration for real-time experiment feedback. |
# | **Perlmutter** (NERSC, LBNL) | Lawrence Berkeley | GPU-accelerated system for turbulence modeling, diagnostics data pipelines, and reduced-order modeling. Widely used for hybrid CPU–GPU workloads. |
# | **Jupiter** (EuroHPC, Jülich) | Germany | Europe’s exascale-class system (operational mid-2025). High energy efficiency and modular design make it a testbed for sustainable fusion computing strategies. |
#
# ---
#
# ### 🧑‍🔬 Why These Systems Matter for Fusion
#
# 1. **Nonlinear, Multiscale Physics**
#    Fusion simulations span **10+ orders of magnitude** in time and space. Capturing phenomena like plasma microturbulence, magnetic reconnection, and wall-material interactions requires exascale resources and advanced parallelism.
#
# 2. **Workload Diversity**
#    - **GPU-intensive ML** (e.g., plasma disruption predictors) excels on Perlmutter and Aurora.
#    - **PDE-heavy solvers** (e.g., gyrokinetic simulations) benefit from Frontier’s bandwidth and latency characteristics.
#    - **Multi-physics pipelines**, integrating simulation + diagnostics data, leverage El Capitan’s heterogeneous compute nodes.
#
# 3. **Energy Efficiency and Scaling**
#    DOE facilities increasingly optimize **science per watt**. Green500 metrics now influence allocation policies, especially for energy-intensive workflows like long-running plasma stability simulations.
#
# 4. **Real-time Experiment Integration**
#    Modern HPC workflows feed data from live fusion experiments into predictive models for **near-real-time control**—critical for both tokamak operations and inertial confinement experiments.
#
# ---
#
# ### 📚 Further Reading & Academic Resources
#
# #### DOE & Facility Reports
# - [DOE Fusion Energy Sciences (FES) Strategic Plan 2024–2034](https://science.osti.gov/fes)
# - [ASCR Computing Facilities & Fusion Science Report (2024)](https://www.osti.gov/servlets/purl/2200012)
# - [NERSC Science Highlights — Fusion Energy](https://www.nersc.gov/news-publications/science-highlights/)
#
# #### Key Academic References
#
# - **Garcia-Gasulla, M., & Mantsinen, M. J.** (2025). Challenges and opportunities in exascale fusion simulations. *Nature Reviews Physics, 7*(5), 355–364. https://doi.org/10.1038/s42254-025-00830-8
#   [Read on Nature](https://www.nature.com/articles/s42254-025-00830-8)
#
# - **Jenko, F.** (2025). Accelerating fusion research via supercomputing. *Nature Reviews Physics, 7*(5), 365–377. https://doi.org/10.1038/s42254-025-00837-1
#   [Read on Nature](https://www.nature.com/articles/s42254-025-00837-1)
#
# - **Battye, M. I., & Perinpanayagam, S.** (2025). Digital twins in fusion energy research: Current state and future directions. *IEEE Access, 13*, 75787–75821. https://doi.org/10.1109/ACCESS.2025.3561920
#   [Read on IEEE Xplore](https://ieeexplore.ieee.org/abstract/document/10967494)
#
# **How to Use These References in Your Project:**
# - The **Garcia-Gasulla & Mantsinen (2025)** article provides a high-level landscape of the computational challenges for fusion research at exascale, making it useful for workload planning discussions.
# - **Jenko (2025)** gives an in-depth look at algorithmic and code-architecture optimizations that can inspire your own efficiency scenarios.
# - **Battye & Perinpanayagam (2025)** offers a forward-looking view into how *digital twins* might transform HPC fusion workflows—valuable for considering long-term DOE strategies.
#
# These papers complement the system-level and efficiency analyses from earlier modules by adding state-of-the-art perspectives from current (2025) fusion computing research.
#
#
# #### Benchmarking & Performance Studies
# - [TOP500 & Green500 Lists](https://top500.org) — current system performance rankings.
# - [ECP Application Benchmarks: XGC, GENE, M3D-C1](https://www.exascaleproject.org) — performance results for major fusion codes.
# - **Chang, C.S. et al.** (2023). *Performance-portable fusion simulations on exascale-class platforms.* *SC23 Proceedings*, IEEE.
#
# ---
#
# > As you move into **Module 5**, refer to these resources to inform your theoretical reasoning on scheduling, workload optimization, and architecture targeting for fusion HPC. Think like both a scientist and a system architect—balancing **science impact, performance, and energy efficiency**.

# %% [markdown]
# ## 🇺🇸 National Strategy: The DOE Fusion Energy Vision
#
# The **U.S. Department of Energy (DOE)** is pursuing one of the most ambitious scientific and engineering challenges of our time—bringing **commercial fusion energy** to reality. Guided by the **Fusion Energy Strategy 2024** and the **Fusion Energy Sciences (FES) Building Bridges Vision**, the DOE aims to transition fusion from experimental science to a deployable, carbon-free energy source within the next decade.
#
# Fusion is no longer just a “future hope” — it’s on a strategic fast track. HPC systems, advanced diagnostics, and AI-driven modeling are critical enablers of this transition, and the DOE is placing high-performance computing at the heart of its strategy.
#
# ### 🚀 Key Strategic Pillars
#
# - **Commercial Deployment by the 2030s**
#   Public-private partnerships will accelerate the development of pilot plants, creating pathways for industrial-scale deployment of fusion systems. This includes supporting companies designing compact, cost-efficient reactors, and aligning national laboratories with industry R&D timelines.
#
# - **Closing Critical Technology Gaps**
#   Targeted research investments are focusing on:
#   - **Materials under extreme conditions** (neutron irradiation, plasma-facing components)
#   - **Advanced magnetic confinement** for higher efficiency and stability
#   - **Tritium fuel cycle handling** for sustainable operation
#   - **Superconducting magnet innovation** for smaller, cheaper, and more efficient designs
#
# - **Integrated Research Infrastructure (IRI)**
#   Fusion research now operates in a **cyber-physical ecosystem**:
#   - Experimental facilities (tokamaks, stellarators, laser-driven systems)
#   - HPC centers like **NERSC**, **OLCF**, and **ALCF** for real-time simulation and analysis
#   - **ESnet** for high-bandwidth, low-latency data transfer between experiment and computation
#
# - **Workforce Development & Equity Goals**
#   Building a next-generation fusion workforce that reflects the diversity of the nation is a priority. This includes DOE-supported fellowships, internships, and programs that bridge academia, industry, and national labs. Outreach and education initiatives aim to broaden participation in fusion research.
#
# ---
#
# ### 🔗 Strategic Context for This Bootcamp Module
#
# For HPC Bootcamp participants, this vision provides the **real-world backdrop** for your theoretical and analytical fusion projects. The skills and concepts from earlier modules—such as **performance optimization, energy efficiency, and workload profiling**—mirror the decision-making challenges facing DOE scientists and engineers:
#
# - How do we **prioritize workloads** on limited power budgets?
# - What’s the **trade-off between simulation fidelity and turnaround time** for real-time control systems?
# - How can HPC guide **design iteration** for future reactors before billions are invested in construction?
#
# By working on the **fusion-themed analysis projects** in this module, you’ll not only sharpen your data analysis and computational reasoning, but also gain perspective on **how HPC directly impacts the timeline for achieving practical fusion power**.
#
# ---
#
# 📘 [DOE Fusion Energy Sciences](https://www.energy.gov/science/fes/fusion-energy-sciences)
# 📘 [Fusion Energy Strategy 2024 PDF](https://science.osti.gov/-/media/fes/pdf/program-documents/FES-Fusion-Energy-Strategy-2024.pdf)
# 📗 *Building Bridges: FES Vision* (2023 White Paper)
# 📚 Sweeney, M. A., et al. (2023). *The U.S. Fusion Strategy: From Science to Commercialization*. *Fusion Science and Technology*. https://doi.org/10.1080/15361055.2023.2180935

# %% [markdown]
# ## 🔬 DOE Facilities and Fusion Experiments
#
# The U.S. fusion ecosystem is anchored by world-class experimental facilities operating under the DOE Office of Science. These serve as both testbeds and data generators for fusion science and HPC modeling:
#
# - **DIII-D National Fusion Facility (GA, San Diego)**: The largest operational U.S. tokamak, contributing real-time profile diagnostics, disruption prediction data, and simulation validation.
# - **NSTX-U (Princeton Plasma Physics Lab)**: Focused on spherical tokamak physics, currently undergoing major upgrades after hardware failures.
# - **NIF (Lawrence Livermore National Laboratory)**: Inertial confinement facility where the first ignition-level fusion event occurred in Dec 2022, producing >3 MJ of energy.
#
# These experiments are deeply integrated with computational workflows. DIII-D, for example, sends real-time diagnostic data via **ESnet** to **NERSC’s Perlmutter**, where plasma reconstructions using MHD codes (e.g., EFIT++, TRANSP) guide experimental decisions within minutes.
#
# 📚 References:
# - [DIII-D and HPC Integration](https://www.ga.com/diii-d-national-fusion-facility-nersc-and-esnet-collaboration-speeds-nuclear-fusion-research)
# - Hittinger, J. A., et al. (2023). *Accelerating Fusion Science with Integrated Infrastructure*. J. Comp. Plasma Physics

# %% [markdown]
# ## 🔥 Hands-On Activity: Fusion Facility Utilization Heatmap
#
# Using the synthetic dataset, let’s analyze HPC usage patterns across different DOE fusion experiments and facilities.
#
# We’ll create a heatmap showing average runtime (in minutes) by facility and project type.
#
# This helps reveal which fusion centers are most HPC-intensive — useful for resource planning and infrastructure scaling.

# %% [markdown]
# ## 🔥 Hands-On Activity: Fusion Facility Utilization Heatmap
#
# High-performance computing (HPC) is the engine behind modern fusion energy breakthroughs.
# Every plasma instability tamed, every material tested against reactor-scale heat flux, and every new confinement strategy explored begins with *petabytes* of simulation data — much of it generated on the most powerful machines in the world.
#
# In this activity, we’ll work with a **synthetic but realistic dataset** representing HPC workloads from several fusion experiments and facilities, mapped to current leadership-class supercomputers:
#
# ### 🔷 Notable Supercomputers (2025)
#
# | System       | Facility | Highlights |
# |--------------|----------|------------|
# | **El Capitan** (LLNL) | Lawrence Livermore | World’s fastest supercomputer as of June 2025 (1.742 exaFLOPS Rmax). CPU–GPU APU design supports advanced fusion materials modeling, chamber-scale plasma simulations, and multi-physics workflows. |
# | **Frontier** (ORNL) | Oak Ridge | DOE’s first exascale system (~1.35 exaFLOPS). Used extensively for codes like CGYRO and XGC to study edge plasma turbulence, confinement optimization, and disruption prediction. |
# | **Aurora** (ANL) | Argonne | Intel/Cray exascale platform (1+ exaFLOPS) powering integrated fusion simulations, ML-based plasma control, and workflow orchestration for real-time experiment feedback. |
# | **Perlmutter** (NERSC, LBNL) | Lawrence Berkeley | GPU-accelerated system for turbulence modeling, diagnostics data pipelines, and reduced-order modeling. Widely used for hybrid CPU–GPU workloads. |
# | **Jupiter** (EuroHPC, Jülich) | Germany | Europe’s exascale-class system (operational mid-2025). High energy efficiency and modular design make it a testbed for sustainable fusion computing strategies. |
# | **Fugaku** (RIKEN) | Japan | ARM-based system with hybrid workloads for plasma control AI and real-time experimental data analysis at facilities like JT-60SA. |
# | **LUMI** (EuroHPC, Finland) | Finland | Energy-efficient, hydro-powered supercomputer running large-scale fusion turbulence studies for European DEMO design. |
# | **Leonardo** (EuroHPC, Italy) | Italy | Focused on hybrid CPU–GPU workloads; supports gyrokinetic simulations for stellarator and tokamak design. |
# | **Henri** (CEA, France) | France | Supports ITER-related materials and plasma simulations; optimized for high I/O workloads. |
# | **Shaheen III** (KAUST) | Saudi Arabia | Large-scale simulations for fusion materials under extreme heat and neutron flux. |
# | **Setonix** (Pawsey Centre, Australia) | Australia | GPU-rich system used for advanced plasma modeling and diagnostics imaging workflows. |
#
# ---
# ### 📍 Fusion Projects & Their HPC Homes
#
# | Fusion Project | Primary Research Focus | Common HPC Home(s) |
# |----------------|------------------------|--------------------|
# | **DIII-D** (General Atomics) | Magnetic confinement physics, turbulence suppression, transport modeling | **Perlmutter (NERSC)** for turbulence modeling, **Frontier (ORNL)** for large-scale MHD simulations |
# | **NSTX-U** (Princeton Plasma Physics Laboratory) | Spherical tokamak design, high-beta plasma experiments | **Frontier (ORNL)** for MHD stability studies, **Aurora (ANL)** for gyrokinetic edge turbulence |
# | **NIF** (National Ignition Facility, LLNL) | Inertial confinement fusion (ICF), laser–plasma interactions | **El Capitan (LLNL)** for laser-plasma coupling and hohlraum modeling |
# | **SPARC** (MIT/CFS) | Compact high-field tokamak, rapid path to commercial fusion | **Aurora (ANL)** for real-time ML control systems, **Perlmutter (NERSC)** for validation simulations |
# | **ITER Physics Support** (CEA, EuroFusion) | Plasma control for ITER device, edge localized mode suppression | **Jupiter (EuroHPC)**, **Henri (CEA)**, **LUMI (Finland)** |
#
#
# Our fusion experiments for this dataset include:
# - **DIII-D** – Magnetic confinement experiments, focusing on plasma stability and transport.
# - **NSTX-U** – Spherical tokamak facility exploring high-beta plasma physics.
# - **NIF** – National Ignition Facility, using lasers for inertial confinement fusion research.
# - **SPARC** – Compact high-field tokamak by MIT/CFS, exploring fast-track pathways to commercial fusion.
#
# We’ll use these to create a **heatmap** showing **average job runtime (in minutes)** by *facility* and *fusion project*.
# This will help us visualize **where HPC demand is highest** and start discussions about **resource allocation** and **scaling strategies**.
#
# 💡 **Questions to consider while you work:**
# - Which facilities appear to be the most HPC-intensive for fusion?
# - Which projects consume the most compute per job?
# - How might workload balancing across facilities improve efficiency and reduce bottlenecks?

# %%
## 📊 Setting Up Fusion HPC Dataset

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Synthetic dataset based on realistic HPC workloads in 2025
df = pd.DataFrame({
    'JobID': range(1, 21),
    'Project': [
        'DIII-D', 'NSTX-U', 'NIF', 'SPARC', 'ITER Physics Support',
        'DIII-D', 'NSTX-U', 'NIF', 'SPARC', 'ITER Physics Support',
        'DIII-D', 'NSTX-U', 'NIF', 'SPARC', 'ITER Physics Support',
        'DIII-D', 'NSTX-U', 'NIF', 'SPARC', 'ITER Physics Support'
    ],
    'Facility': [
        'Perlmutter', 'Frontier', 'El Capitan', 'Aurora', 'Jupiter',
        'Perlmutter', 'Aurora', 'El Capitan', 'Aurora', 'LUMI',
        'Frontier', 'Aurora', 'El Capitan', 'Aurora', 'Henri',
        'Perlmutter', 'Frontier', 'El Capitan', 'Aurora', 'Jupiter'
    ],
    'Cores': [
        512, 1024, 2048, 4096, 8192,
        1024, 2048, 4096, 1024, 4096,
        2048, 4096, 8192, 4096, 2048,
        1024, 1024, 4096, 8192, 4096
    ],
    'RuntimeMinutes': [
        120, 180, 300, 450, 600,
        110, 150, 420, 300, 500,
        200, 240, 380, 400, 350,
        140, 160, 310, 490, 550
    ],
    'JobType': [
        'Simulation', 'Simulation', 'Post-processing', 'ML', 'Simulation',
        'Simulation', 'ML', 'Post-processing', 'Simulation', 'Simulation',
        'Simulation', 'Simulation', 'ML', 'ML', 'Post-processing',
        'ML', 'Simulation', 'Simulation', 'Post-processing', 'Simulation'
    ],
    'Energy_kWh': [
        150, 320, 600, 950, 1600,
        145, 500, 850, 720, 1500,
        300, 640, 1100, 980, 890,
        210, 350, 980, 1400, 1550
    ]
})

# Quick preview
df.head()
# Out:
#    JobID               Project    Facility  Cores  RuntimeMinutes  \
# 0      1                DIII-D  Perlmutter    512             120
# 1      2                NSTX-U    Frontier   1024             180
# 2      3                   NIF  El Capitan   2048             300
# 3      4                 SPARC      Aurora   4096             450
# 4      5  ITER Physics Support     Jupiter   8192             600
#
#            JobType  Energy_kWh
# 0       Simulation         150
# 1       Simulation         320
# 2  Post-processing         600
# 3               ML         950
# 4       Simulation        1600

# %%
# --- Heatmap: Average runtime by Facility and Project (with counts, ordered columns) ---

import numpy as np

# Desired column order to match the 2025 systems list
facility_order = [
    "Perlmutter", "Frontier", "El Capitan", "Aurora", "Jupiter",
    "LUMI", "Henri", "Leonardo", "Fugaku", "Shaheen III", "Setonix"
]

# Build pivot tables for mean and counts
mean_pivot = df.pivot_table(
    index="Project", columns="Facility", values="RuntimeMinutes", aggfunc="mean"
)
count_pivot = df.pivot_table(
    index="Project", columns="Facility", values="RuntimeMinutes", aggfunc="count"
)

# Reindex columns to the desired order; keep only those that appear
present_cols = [c for c in facility_order if c in mean_pivot.columns]
mean_pivot = mean_pivot.reindex(columns=present_cols)
count_pivot = count_pivot.reindex(columns=present_cols)

# Create a matching annotation array: "mean (n)" or blank for NaN
annot = mean_pivot.copy().astype(object)
for r in mean_pivot.index:
    for c in mean_pivot.columns:
        val = mean_pivot.loc[r, c]
        n = count_pivot.loc[r, c]
        annot.loc[r, c] = "" if (pd.isna(val) or pd.isna(n) or n == 0) else f"{val:.0f} ({int(n)})"

plt.figure(figsize=(12, 7))
sns.heatmap(
    mean_pivot, annot=annot, fmt="", cmap="YlGnBu",
    linewidths=0.5, linecolor="gray", cbar_kws={"label": "Average Runtime (minutes)"}
)
plt.title("Average Job Runtime by Facility and Fusion Project", fontsize=14, fontweight="bold")
plt.ylabel("Fusion Project", fontsize=12)
plt.xlabel("HPC Facility", fontsize=12)
plt.xticks(rotation=30, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# --- Optional: Row-normalized heatmap (each project scaled to 0–1 across facilities) ---
# This helps compare which facility is 'slow/fast' per project regardless of absolute minutes.

row_min = mean_pivot.min(axis=1)
row_max = mean_pivot.max(axis=1)
norm = (mean_pivot.sub(row_min, axis=0)).div((row_max - row_min).replace(0, np.nan), axis=0)

plt.figure(figsize=(12, 7))
sns.heatmap(
    norm, annot=False, cmap="viridis",
    linewidths=0.5, linecolor="gray", cbar_kws={"label": "Row-normalized Runtime (0–1)"}
)
plt.title("Relative Runtime by Facility (Row-normalized per Project)", fontsize=14, fontweight="bold")
plt.ylabel("Fusion Project", fontsize=12)
plt.xlabel("HPC Facility", fontsize=12)
plt.xticks(rotation=30, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🤖 AI & Machine Learning in Fusion Research
#
# Artificial Intelligence (AI) and Machine Learning (ML) are emerging as powerful tools in fusion energy R&D. These techniques are being used to:
#
# - **Predict Disruptions**: ML models trained on DIII-D plasma shots predict disruptions with >90% accuracy (Kates-Harbeck et al., 2019).
# - **Guide Magnetic Control**: Reinforcement learning (RL) agents are being tested to control plasma shape in real time.
# - **Accelerate Simulation Workflows**: Surrogate models reduce compute time for gyrokinetic codes by orders of magnitude.
#
# ### 🧪 SciDAC Initiatives
# The DOE’s **Scientific Discovery through Advanced Computing (SciDAC)** program supports AI/ML infusion in MHD modeling, turbulence prediction, and materials degradation analysis.
#
# Discussion Prompt:
# > *How could AI be deployed in fusion reactors to make control decisions under uncertainty? What tradeoffs exist between accuracy, speed, and interpretability?*
#
# 🧠 [Learn more about SciDAC](https://www.scidac.gov/about.html)
# 📚 Kates-Harbeck, J., et al. (2019). *Predicting disruptive instabilities in fusion plasmas using deep learning*. Nature.

# %% [markdown]
# ## 🏛️ Policy, Startups & Commercialization
#
# Fusion is no longer a distant ambition—it's an active area of commercialization with strong federal backing.
#
# ### 🔹 DOE Support
# - **$1.4B in milestone-based grants** support U.S. fusion startups advancing toward pilot plants by the 2030s.
# - **Clean energy tax credit eligibility** (post-IRA) supports demo plant financing.
# - **TINEX** (Tokamak Innovation Network for Experimentation) is driving U.S. tokamak engineering innovation.
#
# ### 🔹 Leading Private Companies
# - **Commonwealth Fusion Systems (CFS)** – MIT spinoff targeting net energy by 2026.
# - **Helion Energy** – Field-reversed configuration with private PPAs.
# - **Zap Energy, TAE, General Fusion** – Each pursuing alternate confinement approaches.
#
# ### 🔹 Workforce Initiatives
# - DOE and NSF fund workforce pipelines like the **FIRE Collaboratives** and **SCGSR Fellowship**.
# - Broader inclusion goals target MSIs and underrepresented groups.
#
# Discussion Prompt:
# > *Should the government continue subsidizing fusion if early commercial plants prove viable? What role does regulation play in ensuring safety and public trust?*
#
# 📗 [CATF Analysis on U.S. Fusion Policy](https://www.catf.us/2025/06/fusion-energy-opportunities-federal-action-support-energy-innovation-commercialization/)
# 📊 [DOE FOA 2025](https://science.osti.gov/grants/FOAs/-/media/grants/pdf/foas/2025/DE-FOA-0003516-000002.pdf)
